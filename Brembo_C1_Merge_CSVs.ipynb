# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def merge(arr):
  dfs = []
  for item in arr:
    dfs.append(pd.read_csv(item))

  return pd.concat(dfs)

# %%
# !ls drive/MyDrive/BremboLocal
# Out:
# Sub3.csv	  submission_data.csv  test_mantek19.csv   test_vineet16.csv
# submission_3.csv  test_gagan_14.csv    test_prateek11.csv

# %%
main_df = merge([
    'drive/MyDrive/BremboLocal/submission_data.csv', 'drive/MyDrive/BremboLocal/test_gagan_14.csv', 'drive/MyDrive/BremboLocal/test_gagan_13.csv'

])
main_df.to_csv('submission_4.csv', index=False)

# %%
main_df
# Out:
#       time_index          compound_id               step           braking_id  \
# 0              1  new-compound1857113       Burnishing 1       burnishing_1_1
# 1              2  new-compound1857113       Burnishing 1       burnishing_1_1
# 2              3  new-compound1857113       Burnishing 1       burnishing_1_1
# 3              4  new-compound1857113       Burnishing 1       burnishing_1_1
# 4              5  new-compound1857113       Burnishing 1       burnishing_1_1
# ...          ...                  ...                ...                  ...
# 3839        3840   new-compound400217   Characteristic 7   characteristic_7_3
# 3840        3841   new-compound400217   Characteristic 7   characteristic_7_3
# 3841        3842   new-compound400217   Characteristic 7   characteristic_7_3
# 3842        3843   new-compound400217   Characteristic 7   characteristic_7_3
# 3843        3844   new-compound400217   Characteristic 7   characteristic_7_3
#
# ...

# %%
ddff = pd.read_csv('submission_data.csv')

# %%
ddff
# Out:
#        time_index           compound_id               step  \
# 0               1   new-compound1857113       Burnishing 1
# 1               2   new-compound1857113       Burnishing 1
# 2               3   new-compound1857113       Burnishing 1
# 3               4   new-compound1857113       Burnishing 1
# 4               5   new-compound1857113       Burnishing 1
# ...           ...                   ...                ...
# 53811        3840   new-compound9172754   Characteristic 7
# 53812        3841   new-compound9172754   Characteristic 7
# 53813        3842   new-compound9172754   Characteristic 7
# 53814        3843   new-compound9172754   Characteristic 7
# 53815        3844   new-compound9172754   Characteristic 7
#
#                 braking_id     time  pressure_bar     temp_c  speed_kph  \
# 0           burnishing_1_1  0.92000      11.48600   30.02500   73.62800
# 1           burnishing_1_1  1.00467      10.33317   30.63500   72.07230
# ...
